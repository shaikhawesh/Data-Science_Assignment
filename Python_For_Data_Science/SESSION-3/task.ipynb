# %%
age = 20
height = 173.73
name = "Awesh Shaikh"
spotify_acc = False

print(f"Your Name is:{name}", type(name))
print(f"Your Age is:{age}", type(age))
print(f"Your Height is:{height}", type(height))
print(f"Do you have Spotify Account:{spotify_acc}", type(spotify_acc))
# Out:
# Your Name is:Awesh Shaikh <class 'str'>
# Your Age is:20 <class 'int'>
# Your Height is:173.73 <class 'float'>
# Do you have Spotify Account:False <class 'bool'>
